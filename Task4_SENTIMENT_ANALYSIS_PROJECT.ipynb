# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajneesh35/CodeAlpha_Task4_SENTIMENT-ANALYSIS-PROJECT/blob/main/Task4_SENTIMENT_ANALYSIS_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob


import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt


df = pd.read_csv("quotes_dataset.csv")


def analyze_sentiment(text):
    analysis = TextBlob(str(text))
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"


df["Sentiment"] = df["Quote"].apply(analyze_sentiment)


print("Sample Data with Sentiment:")
print(df.head())


sentiment_counts = df["Sentiment"].value_counts()

print("\nSentiment Distribution:")
print(sentiment_counts)


plt.figure()
sentiment_counts.plot(kind="bar")
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Quotes")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()


df.to_csv("quotes_with_sentiment.csv", index=False)

print("\nTask Completed Successfully!")
print("New file saved as: quotes_with_sentiment.csv")
# Out:
# ...
# Sample Data with Sentiment:
#                                                Quote       Author  Tags  \
# 0  Life is what happens when you're busy making o...  John Lennon  life
#
#   Sentiment
# 0  Negative
#
# Sentiment Distribution:
# Sentiment
# Negative    1
# Name: count, dtype: int64
# Task Completed Successfully!
# New file saved as: quotes_with_sentiment.csv
